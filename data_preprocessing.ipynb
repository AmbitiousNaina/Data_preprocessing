# %%
import pandas as pd
df = pd.read_csv('/content/sample.csv')

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.isna()
# Out:
#    Country    Age  Salary  Purchased
# 0    False  False   False      False
# 1    False  False   False      False
# 2    False  False   False      False
# 3    False  False   False      False
# 4    False  False    True      False
# 5    False  False   False      False
# 6    False   True   False      False
# 7    False  False   False      False
# 8    False  False   False      False
# 9    False  False   False      False

# %%
df.isna().sum()
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
df.isna().sum()/len(df)*100
# Out:
# Country       0.0
# Age          10.0
# Salary       10.0
# Purchased     0.0
# dtype: float64

# %%
df.dropna()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.fillna(70)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0     70.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  70.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.fillna(df.max())
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  83000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  50.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.fillna(df.min())
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  48000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  27.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
print(df.fillna(df.mean()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-3f8c17285f79> in <cell line: 1>()
# ----> 1 print(df.fillna(df.mean()))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11333         **kwargs,
#   11334     ):
# > 11335         result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11336         if isinstance(result, Series):
#   11337             result = result.__finalize__(self, method="mean")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11990         **kwargs,
#   11991     ) -> Series | float:
# > 11992         return self._stat_function(
#   11993             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11994         )
#
# ...

# %%
avg = df["Salary"].dropna().mean()
avg
# Out:
# 63777.77777777778

# %%
df['Salary'].fillna(avg, inplace=True)
df
# Out:
#    Country   Age        Salary Purchased
# 0   France  44.0  72000.000000        No
# 1    Spain  27.0  48000.000000       Yes
# 2  Germany  30.0  54000.000000        No
# 3    Spain  38.0  61000.000000        No
# 4  Germany  40.0  63777.777778       Yes
# 5   France  35.0  58000.000000       Yes
# 6    Spain   NaN  52000.000000        No
# 7   France  48.0  79000.000000       Yes
# 8  Germany  50.0  83000.000000        No
# 9   France  37.0  67000.000000       Yes

# %%
df=pd.read_csv("sample.csv")
print(df)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
avgValue = df["Age"].dropna().mean()
avgsal = df["Salary"].dropna().mean()
df['Age']=df["Age"].fillna(avgValue)
df['Salary']=df["Salary"].fillna(avgsal)
print(df)
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %%
print(df)
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %%
df=pd.read_csv("sample.csv")
print(df)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
print(df.interpolate())
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes
# <ipython-input-21-311e767c39a1>:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   print(df.interpolate())

# %%
import numpy as np

# %%
df.replace(48, np.nan, inplace=True)

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France   NaN  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df['Age1']=[44,27,30,38,40,35,'Nan','Nan',50,37]
df['Age']=df['Age1']

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France   NaN  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.replace(44,77)
# Out:
#    Country  Age   Salary Purchased Age1
# 0   France   77  72000.0        No   77
# 1    Spain   27  48000.0       Yes   27
# 2  Germany   30  54000.0        No   30
# 3    Spain   38  61000.0        No   38
# 4  Germany   40      NaN       Yes   40
# 5   France   35  58000.0       Yes   35
# 6    Spain  Nan  52000.0        No  Nan
# 7   France  Nan  79000.0       Yes  Nan
# 8  Germany   50  83000.0        No   50
# 9   France   37  67000.0       Yes   37

# %%
import numpy as np

# %%
df['Age'].replace(to_replace = np.nan, value=36, inplace = True)
print(df)
# Out:
#    Country  Age   Salary Purchased Age1
# 0   France   44  72000.0        No   44
# 1    Spain   27  48000.0       Yes   27
# 2  Germany   30  54000.0        No   30
# 3    Spain   38  61000.0        No   38
# 4  Germany   40  36000.0       Yes   40
# 5   France   35  58000.0       Yes   35
# 6    Spain  Nan  52000.0        No  Nan
# 7   France  Nan  79000.0       Yes  Nan
# 8  Germany   50  83000.0        No   50
# 9   France   37  67000.0       Yes   37

# %%
df['Salary'].replace(to_replace=np.nan, value=36000, inplace=True)
df
# Out:
#    Country  Age   Salary Purchased Age1
# 0   France   44  72000.0        No   44
# 1    Spain   27  48000.0       Yes   27
# 2  Germany   30  54000.0        No   30
# 3    Spain   38  61000.0        No   38
# 4  Germany   40  36000.0       Yes   40
# 5   France   35  58000.0       Yes   35
# 6    Spain  Nan  52000.0        No  Nan
# 7   France  Nan  79000.0       Yes  Nan
# 8  Germany   50  83000.0        No   50
# 9   France   37  67000.0       Yes   37

# %%
print(df)
# Out:
#    Country  Age   Salary Purchased Age1
# 0   France   44  72000.0        No   44
# 1    Spain   27  48000.0       Yes   27
# 2  Germany   30  54000.0        No   30
# 3    Spain   38  61000.0        No   38
# 4  Germany   40  36000.0       Yes   40
# 5   France   35  58000.0       Yes   35
# 6    Spain  Nan  52000.0        No  Nan
# 7   France  Nan  79000.0       Yes  Nan
# 8  Germany   50  83000.0        No   50
# 9   France   37  67000.0       Yes   37

# %%
df = pd.read_csv('/content/sample.csv')
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df['Age'].replace(to_replace = np.nan, value=36, inplace = True)
print(df)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  36.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df['Salary'].replace(to_replace=np.nan, value=36000, inplace=True)
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  36000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  36.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
bins = [20,30,40,50]
group_name = ['Youth', 'Adult', 'Senior']
df['Age_category'] = pd.cut(df['Age'], bins , labels = group_name)
print(df)
# Out:
#    Country   Age   Salary Purchased Age_category
# 0   France  44.0  72000.0        No       Senior
# 1    Spain  27.0  48000.0       Yes        Youth
# 2  Germany  30.0  54000.0        No        Youth
# 3    Spain  38.0  61000.0        No        Adult
# 4  Germany  40.0  36000.0       Yes        Adult
# 5   France  35.0  58000.0       Yes        Adult
# 6    Spain  36.0  52000.0        No        Adult
# 7   France  48.0  79000.0       Yes       Senior
# 8  Germany  50.0  83000.0        No       Senior
# 9   France  37.0  67000.0       Yes        Adult
